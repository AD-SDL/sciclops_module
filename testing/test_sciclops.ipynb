# %%
# from sciclops_interface_OLD import SCICLOPS
from resource_helpers.sciclops_resource_defs import locations, plate_definitions
from sciclops_driver import SCICLOPS

# locations
home_location = locations["Home"]
safe_location = locations["Safe"]
stack1_location = locations["Stack1"]
stack2_location = locations["Stack2"]
lid_nest_1_location = locations["LidNest1"]

# plate types
flat_plate = plate_definitions["flat_bottom_96well"]

# SciClops instance
s = SCICLOPS()
# Out:
# Device Connected
# <<<
# Sending command: STATUS
# Response:
# STATUS
# 0000 0
#
# >>>

# %%
s.get_current_position()
# Out:
# <<<
# Sending command: GETPOS
# Response:
# GETPOS
# 0000 Z:0.0000, R:0.0000, Y:0.0310, P:1.1080
#
# >>>
# [0.0, 0.0, 0.031, 1.108]

# %%
s.move(
    R=safe_location.joint_angles["R"],
    Z=safe_location.joint_angles["Z"],
    P=safe_location.joint_angles["P"],
    Y=safe_location.joint_angles["Y"],
)
# Out:
# <<<
# Sending command: LOADPOINT TEMP, Z:23.5188, P:98.2955, Y:32.7484, R:109.2741
# Response:
# LOADPOINT TEMP, Z:23.5188, P:98.2955, Y:32.7484, R:109.2741
# 0000 Success
#
# >>>
# <<<
# Sending command: MOVE TEMP
# Response:
# MOVE TEMP
# 1204 Z axis not homed.
#
# >>>
# <<<
# Sending command: STATUS
# Response:
# STATUS
# 0000 0
#
# >>>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s.move(
#       2     R=safe_location.joint_angles["R"],
#       3     Z=safe_location.joint_angles["Z"],
#       4     P=safe_location.joint_angles["P"],
#
# File ~/workspace/sciclops_module/src/sciclops_driver.py:395, in SCICLOPS.move(self, R, Z, P, Y)
#     393 response = self.send_command("MOVE TEMP\r\n")
#     394 if status := self.get_status() != "1":
# --> 395     raise Exception(f"Move failed, status code {status}")
#     396 response_codes = self.get_response_codes(response)
#     397 if [response_code for response_code in response_codes if response_code != 0]:
#
# Exception: Move failed, status code True

# %%
# s.move_loc(home_location)
# s.gripper_open()
s.gripper_close()
# Out:
# <<<
# Sending command: CLOSE
# Response:
# CLOSE
# 0000 Success
#
# >>>
# 'CLOSE\r\n0000 Success\r\n'

# %%
s.move_above_loc(stack1_location)

# %%
s.home()
# Out:
# <<<
# Sending command: HOME
# Response:
# HOME
# 0000 All Axes Homed
#
# >>>
# 'HOME\r\n0000 All Axes Homed\r\n'

# %%
s.get_status()

# %%
s.gripper_open()

# %%
s.jog("Y", -200)

# %%
s.pick_plate_direct(
    source=lid_nest_1_location,
    plate_type=flat_plate,
    has_lid=True,
)

s.place_plate_direct(
    target=stack1_location,
    plate_type=flat_plate,
)

# %%
s.limp(True)

# %%
s.disconnect_robot()
